# %%
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import numpy as np

# %%
path = '/Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/entregable/'
filename = 'results.csv'

results = read_csv(path+filename)

# %%
results
# Out:
#     Index              Model              Group  Minimum  Average  Maximum
# 0       1      Average basic    Adversity - Std    0.028    0.152    0.430
# 1       2      Average basic    Adversity - ToU    0.058    0.158    0.273
# 2       3      Average basic     Affluent - Std    0.025    0.171    0.526
# 3       4      Average basic     Affluent - ToU    0.076    0.166    0.349
# 4       5      Average basic  Comfortable - Std    0.001    0.147    0.437
# 5       6      Average basic  Comfortable - ToU    0.079    0.141    0.254
# 6       7     Average Weekly    Adversity - Std    0.022    0.130    0.369
# 7       8     Average Weekly    Adversity - ToU    0.051    0.139    0.226
# 8       9     Average Weekly     Affluent - Std    0.026    0.149    0.472
# 9      10     Average Weekly     Affluent - ToU    0.060    0.144    0.299
# 10     11     Average Weekly  Comfortable - Std    0.002    0.128    0.424
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
# Model      30 non-null object
# Group      30 non-null object
# Minimum    30 non-null float64
# Average    30 non-null float64
# Maximum    30 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 1.2+ KB

# %%
avg_basic = results.iloc[0:5]
avg_pro = results.iloc[6:11]
arima = results.iloc[12:17]
lstm_uni = results.iloc[18:23]
lstm_multi = results.iloc[24:29]

# %%
avg_basic
# Out:
#    Index          Model              Group  Minimum  Average  Maximum
# 0      1  Average basic    Adversity - Std    0.028    0.152    0.430
# 1      2  Average basic    Adversity - ToU    0.058    0.158    0.273
# 2      3  Average basic     Affluent - Std    0.025    0.171    0.526
# 3      4  Average basic     Affluent - ToU    0.076    0.166    0.349
# 4      5  Average basic  Comfortable - Std    0.001    0.147    0.437

# %%
plt.figure(figsize = (10,10))
plt.barh(results['Model'],results['Average'])
plt.show()

# %%
labels = ['Average Basic', 'Average Weekly', 'ARIMA','LSTM Univariate','LSTM Multivariate']

indx = np.arange(len(labels))
avg_bais_means = list(avg_basic.T['Average'])
female_means = list(dataset.T['female'])

bar_width = 0.35

fig, ax = plt.subplots()
barMale = ax.bar(indx - bar_width/2, male_means, bar_width, label='Male means')
barFemale = ax.bar(indx + bar_width/2, female_means, bar_width, label='Female means')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-97211ad53dc5> in <module>
#       1 plt.figure(figsize = (10,10))
#       2 plt.bar(range(5),results['Average'][0:5],width = 0.35)
# ----> 3 plt.bar(range(10),results['Average'][6:11],width = 0.35)
#       4 plt.bar(results['Index'][12:17],results['Average'][12:17],width = 0.35)
#       5 plt.bar(results['Index'][18:23],results['Average'][18:23],width = 0.35)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
# -> 2434         **({"data": data} if data is not None else {}), **kwargs)
#    2435
#    2436
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# plot
plt.figure(figsize = (30,20))

plt.subplot(321)
plt.bar(avg_basic['Group'],avg_basic['Average'])
plt.title('Model 1: Average Basic')
plt.ylabel('Average RMSLE')
plt.xlabel('ACORN group - Tariff')
plt.ylim((0,0.2))

plt.subplot(322)
plt.bar(avg_pro['Group'],avg_pro['Average'])
plt.title('Model 2: Average weekly')
plt.xlabel('ACORN group - Tariff')
plt.ylabel('Average RMSLE')
plt.ylim((0,0.2))

plt.subplot(323)
plt.bar(arima['Group'],arima['Average'])
plt.title('Model 3: ARIMA')
plt.xlabel('ACORN group - Tariff')
plt.ylabel('Average RMSLE')
plt.ylim((0,0.2))

plt.subplot(324)
plt.bar(lstm_uni['Group'],lstm_uni['Average'])
plt.title('Model 4: LSTM Univariate')
plt.xlabel('ACORN group - Tariff')
plt.ylabel('Average RMSLE')
plt.ylim((0,0.2))

plt.subplot(325)
plt.bar(lstm_multi['Group'],lstm_multi['Average'])
plt.title('Model 5: LSTM Multivariate')
plt.xlabel('ACORN group - Tariff')
plt.ylabel('Average RMSLE')
plt.ylim((0,0.2))


plt.savefig('/Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/plots/results_bar')
plt.show()
