# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn import metrics
import math
import random

# %%
def rmsle(y, y_pred):     
    assert len(y) == len(y_pred)
    terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
    return (sum(terms_to_sum) * (1.0/len(y))) ** 0.5

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
def lstm_univariate_loop(dataset):
    
    random.seed(1)
    dataset = df.values
    dataset = df.astype('float32')
    
    # normalize the dataset
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(dataset)
    
    # split into train and test sets
    print('Spliting into train and test')
    train_size = int(33600)
    test_size = len(dataset) - train_size
    train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    
    # reshape into X=t and Y=t+1
    look_back = 3
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    testY_copy = testY.copy()
    # reshape input to be [samples, time steps, features]
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    
    # create and fit the LSTM network
    print('Creating and fitting the LSTM network')
    model = Sequential()
    model.add(LSTM(200, input_shape=(1, look_back)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=7,batch_size = 70, verbose=1,validation_split=0.04)
    
    # make predictions
    print('Making predictions')
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)
    
    # invert predictions
    trainPredict = scaler.inverse_transform(trainPredict)
    trainY = scaler.inverse_transform([trainY])
    testPredict = scaler.inverse_transform(testPredict)
    testY = scaler.inverse_transform([testY])
    
    #Metrics
    print('Calculating metrics')
    rmsle_i = rmsle(testY_copy,testPredict)
    
    return rmsle_i

# %%
# load the dataset
path = "/Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/univariate/comfortable_tou"
all_files = glob.glob(path + "/*.csv")

i = 0
rmsle_t = []
for filename in all_files:
    i = i + 1
    print('filename number ' + str(i) + ' of ' + str(len(all_files)))
    df = pd.read_csv(filename)
    df.set_index("tstp", inplace = True)
    rmsle_i = lstm_univariate_loop(df)
    rmsle_t.append(round(rmsle_i,3))
# Out:
# filename number 1 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 2/7
# 32252/32252 [==============================] - 3s 79us/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 3/7
# 32252/32252 [==============================] - 3s 78us/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 4/7
# 32252/32252 [==============================] - 2s 74us/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 5/7
# 32252/32252 [==============================] - 2s 74us/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 6/7
# 32252/32252 [==============================] - 2s 74us/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 7/7
# 32252/32252 [==============================] - 2s 77us/step - loss: 0.0032 - val_loss: 0.0034
# Making predictions
# Calculating metrics
# filename number 2 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 2/7
# 32252/32252 [==============================] - 3s 79us/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 3/7
# 32252/32252 [==============================] - 3s 78us/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 4/7
# 32252/32252 [==============================] - 2s 77us/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 5/7
# 32252/32252 [==============================] - 3s 79us/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 6/7
# 32252/32252 [==============================] - 3s 78us/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 7/7
# 32252/32252 [==============================] - 3s 81us/step - loss: 0.0020 - val_loss: 0.0017
# Making predictions
# Calculating metrics
# filename number 3 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 104us/step - loss: 0.0051 - val_loss: 0.0117
# Epoch 2/7
# 32252/32252 [==============================] - 3s 84us/step - loss: 0.0046 - val_loss: 0.0124
# Epoch 3/7
# 32252/32252 [==============================] - 3s 85us/step - loss: 0.0046 - val_loss: 0.0119
# Epoch 4/7
# 32252/32252 [==============================] - 3s 85us/step - loss: 0.0046 - val_loss: 0.0119
# Epoch 5/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0046 - val_loss: 0.0117
# Epoch 6/7
# 32252/32252 [==============================] - 3s 90us/step - loss: 0.0046 - val_loss: 0.0117
# Epoch 7/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0046 - val_loss: 0.0116
# Making predictions
# Calculating metrics
# filename number 4 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 105us/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 2/7
# 32252/32252 [==============================] - 3s 90us/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 3/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 4/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 5/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 6/7
# 32252/32252 [==============================] - 3s 96us/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 7/7
# 32252/32252 [==============================] - 3s 97us/step - loss: 0.0015 - val_loss: 0.0017
# Making predictions
# Calculating metrics
# filename number 5 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 113us/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 2/7
# 32252/32252 [==============================] - 3s 100us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 3/7
# 32252/32252 [==============================] - 3s 96us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 4/7
# 32252/32252 [==============================] - 3s 98us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 5/7
# 32252/32252 [==============================] - 3s 103us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 6/7
# 32252/32252 [==============================] - 3s 101us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 7/7
# 32252/32252 [==============================] - 3s 99us/step - loss: 0.0027 - val_loss: 0.0022
# Making predictions
# Calculating metrics
# filename number 6 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 112us/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 2/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 3/7
# 32252/32252 [==============================] - 3s 90us/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 4/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 5/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 6/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 7/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0030 - val_loss: 0.0021
# Making predictions
# Calculating metrics
# filename number 7 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 108us/step - loss: 0.0044 - val_loss: 0.0023
# Epoch 2/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 3/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 4/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 5/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 6/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 7/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0039 - val_loss: 0.0023
# Making predictions
# Calculating metrics
# filename number 8 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 109us/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 2/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0050 - val_loss: 0.0062
# Epoch 3/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 4/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 5/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 6/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 7/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0048 - val_loss: 0.0060
# Making predictions
# Calculating metrics
# filename number 9 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 109us/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 2/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 3/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 4/7
# 32252/32252 [==============================] - 3s 93us/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 5/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 6/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 7/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0041 - val_loss: 0.0038
# Making predictions
# Calculating metrics
# filename number 10 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 99us/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 2/7
# 32252/32252 [==============================] - 3s 82us/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 3/7
# 32252/32252 [==============================] - 3s 82us/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 4/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 5/7
# 32252/32252 [==============================] - 3s 92us/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 6/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 7/7
# 32252/32252 [==============================] - 3s 94us/step - loss: 0.0021 - val_loss: 0.0025
# Making predictions
# Calculating metrics
# filename number 11 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 111us/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 2/7
# 32252/32252 [==============================] - 3s 102us/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 3/7
# 32252/32252 [==============================] - 4s 111us/step - loss: 0.0046 - val_loss: 0.0028
# Epoch 4/7
# 32252/32252 [==============================] - 3s 95us/step - loss: 0.0045 - val_loss: 0.0028
# Epoch 5/7
# 32252/32252 [==============================] - 3s 95us/step - loss: 0.0045 - val_loss: 0.0029
# Epoch 6/7
# 32252/32252 [==============================] - 3s 96us/step - loss: 0.0045 - val_loss: 0.0028
# Epoch 7/7
# 32252/32252 [==============================] - 3s 99us/step - loss: 0.0045 - val_loss: 0.0028
# Making predictions
# Calculating metrics
# filename number 12 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 116us/step - loss: 0.0072 - val_loss: 0.0091
# Epoch 2/7
# 32252/32252 [==============================] - 3s 104us/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 3/7
# 32252/32252 [==============================] - 3s 100us/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 4/7
# 32252/32252 [==============================] - 4s 114us/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 5/7
# 32252/32252 [==============================] - 3s 101us/step - loss: 0.0070 - val_loss: 0.0087
# Epoch 6/7
# 32252/32252 [==============================] - 3s 97us/step - loss: 0.0070 - val_loss: 0.0086
# Epoch 7/7
# 32252/32252 [==============================] - 3s 97us/step - loss: 0.0070 - val_loss: 0.0088
# Making predictions
# Calculating metrics
# filename number 13 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 4s 115us/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 2/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0069 - val_loss: 0.0057
# Epoch 3/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 4/7
# 32252/32252 [==============================] - 3s 91us/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 5/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 6/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 7/7
# 32252/32252 [==============================] - 3s 90us/step - loss: 0.0068 - val_loss: 0.0057
# Making predictions
# Calculating metrics
# filename number 14 of 14
# Spliting into train and test
# Creating and fitting the LSTM network
# Train on 32252 samples, validate on 1344 samples
# Epoch 1/7
# 32252/32252 [==============================] - 3s 104us/step - loss: 0.0083 - val_loss: 0.0097
# Epoch 2/7
# 32252/32252 [==============================] - 3s 86us/step - loss: 0.0073 - val_loss: 0.0098
# Epoch 3/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0073 - val_loss: 0.0102
# Epoch 4/7
# 32252/32252 [==============================] - 3s 90us/step - loss: 0.0073 - val_loss: 0.0097
# Epoch 5/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0073 - val_loss: 0.0098
# Epoch 6/7
# 32252/32252 [==============================] - 3s 90us/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 7/7
# 32252/32252 [==============================] - 3s 89us/step - loss: 0.0073 - val_loss: 0.0094
# Making predictions
# Calculating metrics

# %%
plt.figure(figsize = (10,5))
plt.subplot(121)
plt.scatter(range(len(rmsle_t)),rmsle_t,color = 'yellow',alpha = 0.5)
plt.plot(range(len(rmsle_t)),[min(rmsle_t)]*len(rmsle_t),color = 'grey',linestyle = '--')
plt.plot(range(len(rmsle_t)),[round(np.average(rmsle_t),3)]*len(rmsle_t),color = 'grey',linestyle = ':')
plt.plot(range(len(rmsle_t)),[max(rmsle_t)]*len(rmsle_t),color = 'grey',linestyle = '-.')
plt.yticks([min(rmsle_t),round(np.average(rmsle_t),3),max(rmsle_t)],[str(min(rmsle_t)) + ' (Min)',
                                                            str(round(np.average(rmsle_t),3)) + ' (Avg)',
                                                                         str(max(rmsle_t))+' (Max)'])
plt.title('RMSLE scatter plot',fontsize = 12)
plt.xlabel('Households')
plt.ylabel('RMSLE')

plt.subplot(122)
plt.hist(rmsle_t,color = 'yellow',alpha = 0.5)
plt.axvline(x=min(rmsle_t), color='grey', linestyle='--', linewidth=2)
plt.axvline(x=round(np.average(rmsle_t),3), color='grey', linestyle=':', linewidth=2)
plt.axvline(x=max(rmsle_t), color='grey', linestyle='-.', linewidth=2)

plt.title("RMSLE histogram",fontsize = 12)
plt.xlabel('RMSLE')
plt.savefig('/Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/plots/4_lstm_uni/RMSLE_comfortable_tou')

plt.show();
