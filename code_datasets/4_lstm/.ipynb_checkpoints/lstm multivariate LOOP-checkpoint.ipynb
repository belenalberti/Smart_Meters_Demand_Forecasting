# %%
import pandas as pd
from pandas import read_csv
from math import sqrt
import numpy as np
from numpy import concatenate
from matplotlib import pyplot
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn import metrics
import glob
# Out:
# Using TensorFlow backend.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def lstm_multivariate(filename):
    
    values = filename.values
    
    # integer encode direction
    encoder = LabelEncoder()
    values[:,4] = encoder.fit_transform(values[:,4])
    # ensure all data is float
    values = values.astype('float32')
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    # frame as supervised learning
    reframed = series_to_supervised(scaled, 1, 1)
    # drop columns we don't want to predict
    reframed.drop(reframed.columns[[10,11,11,12,13,14,15,16,17]], axis=1, inplace=True)
    print(reframed.head())
    
    
    # split into train and test sets
    print("Splitting into train and test")
    values = reframed.values
    n_train_hours = 33600
    train = values[:n_train_hours, :]
    test = values[n_train_hours:, :]
    # split into input and outputs
    train_X, train_y = train[:, :-1], train[:, -1]
    test_X, test_y = test[:, :-1], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    
    
    # design network
    print("Designing network")
    model = Sequential()
    model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')
   
    # fit network
    print("Fitting network")
    history = model.fit(train_X, train_y, epochs=50, batch_size=70, validation_data=(test_X, test_y), verbose=2, shuffle=False)
    
    
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    pyplot.show()
    
    
    # make a prediction
    yhat = model.predict(test_X)
    test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
    # invert scaling for forecast
    inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,0]
    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]
    
    #Metrics
    print('Calculating metrics')
    mape_i = sMAPE(inv_y, inv_yhat)
    rmsle_i = rmsle(inv_y, inv_yhat)
    
    return mape_i, rmsle_i

# %%
# load the dataset
path = "/Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/"
all_files = glob.glob(path + "/*.csv")

rmse_t = []
mae_t = []
for filename in all_files:
    print(str(filename))
    dataframe = pd.read_csv(filename,parse_dates = ['tstp'], index_col = ['tstp'])
    rmse,mae = lstm_multivariate(dataframe)
    rmse_t.append(rmse)
    mae_t.append(mae)
# Out:
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000049.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.024534   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.015750   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.084507   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.047100   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.038922   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.015750
# 2   0.508475   0.403581   0.909091  0.084507
# 3   0.519855   0.414601   0.870130  0.047100
# 4   0.519855   0.414601   0.870130  0.038922
# 5   0.516465   0.362948   0.883117  0.031501
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0599 - val_loss: 0.0516
# Epoch 2/50
#  - 1s - loss: 0.0544 - val_loss: 0.0511
# Epoch 3/50
#  - 1s - loss: 0.0540 - val_loss: 0.0508
# Epoch 4/50
#  - 1s - loss: 0.0535 - val_loss: 0.0505
# Epoch 5/50
#  - 1s - loss: 0.0532 - val_loss: 0.0503
# Epoch 6/50
#  - 1s - loss: 0.0529 - val_loss: 0.0503
# Epoch 7/50
#  - 1s - loss: 0.0526 - val_loss: 0.0502
# Epoch 8/50
#  - 1s - loss: 0.0524 - val_loss: 0.0502
# Epoch 9/50
#  - 1s - loss: 0.0522 - val_loss: 0.0501
# Epoch 10/50
#  - 2s - loss: 0.0520 - val_loss: 0.0498
# Epoch 11/50
#  - 1s - loss: 0.0519 - val_loss: 0.0497
# Epoch 12/50
#  - 1s - loss: 0.0518 - val_loss: 0.0495
# Epoch 13/50
#  - 1s - loss: 0.0517 - val_loss: 0.0496
# Epoch 14/50
#  - 1s - loss: 0.0517 - val_loss: 0.0496
# Epoch 15/50
#  - 1s - loss: 0.0516 - val_loss: 0.0496
# Epoch 16/50
#  - 1s - loss: 0.0516 - val_loss: 0.0495
# Epoch 17/50
#  - 1s - loss: 0.0515 - val_loss: 0.0496
# Epoch 18/50
#  - 1s - loss: 0.0515 - val_loss: 0.0496
# Epoch 19/50
#  - 1s - loss: 0.0515 - val_loss: 0.0496
# Epoch 20/50
#  - 1s - loss: 0.0515 - val_loss: 0.0495
# Epoch 21/50
#  - 1s - loss: 0.0515 - val_loss: 0.0496
# Epoch 22/50
#  - 1s - loss: 0.0515 - val_loss: 0.0494
# Epoch 23/50
#  - 1s - loss: 0.0515 - val_loss: 0.0495
# Epoch 24/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 25/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 26/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 27/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 28/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 29/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 30/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 31/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 32/50
#  - 1s - loss: 0.0514 - val_loss: 0.0497
# Epoch 33/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 34/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 35/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 36/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 37/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 38/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 39/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 40/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 41/50
#  - 1s - loss: 0.0514 - val_loss: 0.0495
# Epoch 42/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 43/50
#  - 1s - loss: 0.0514 - val_loss: 0.0496
# Epoch 44/50
#  - 1s - loss: 0.0513 - val_loss: 0.0496
# Epoch 45/50
#  - 1s - loss: 0.0513 - val_loss: 0.0496
# Epoch 46/50
#  - 1s - loss: 0.0513 - val_loss: 0.0495
# Epoch 47/50
#  - 1s - loss: 0.0513 - val_loss: 0.0495
# Epoch 48/50
#  - 1s - loss: 0.0513 - val_loss: 0.0495
# Epoch 49/50
#  - 1s - loss: 0.0513 - val_loss: 0.0495
# Epoch 50/50
#  - 1s - loss: 0.0513 - val_loss: 0.0496
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000048.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.023299   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.032914   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.033654   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.031805   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.024408   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.032914
# 2   0.508475   0.403581   0.909091  0.033654
# 3   0.519855   0.414601   0.870130  0.031805
# 4   0.519855   0.414601   0.870130  0.024408
# 5   0.516465   0.362948   0.883117  0.025148
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0232 - val_loss: 0.0152
# Epoch 2/50
#  - 1s - loss: 0.0199 - val_loss: 0.0194
# Epoch 3/50
#  - 2s - loss: 0.0194 - val_loss: 0.0147
# Epoch 4/50
#  - 2s - loss: 0.0191 - val_loss: 0.0160
# Epoch 5/50
#  - 2s - loss: 0.0191 - val_loss: 0.0149
# Epoch 6/50
#  - 2s - loss: 0.0189 - val_loss: 0.0149
# Epoch 7/50
#  - 2s - loss: 0.0190 - val_loss: 0.0145
# Epoch 8/50
#  - 2s - loss: 0.0188 - val_loss: 0.0144
# Epoch 9/50
#  - 2s - loss: 0.0187 - val_loss: 0.0143
# Epoch 10/50
#  - 2s - loss: 0.0187 - val_loss: 0.0149
# Epoch 11/50
#  - 2s - loss: 0.0185 - val_loss: 0.0143
# Epoch 12/50
#  - 2s - loss: 0.0186 - val_loss: 0.0143
# Epoch 13/50
#  - 2s - loss: 0.0186 - val_loss: 0.0144
# Epoch 14/50
#  - 2s - loss: 0.0186 - val_loss: 0.0145
# Epoch 15/50
#  - 2s - loss: 0.0185 - val_loss: 0.0142
# Epoch 16/50
#  - 1s - loss: 0.0184 - val_loss: 0.0143
# Epoch 17/50
#  - 1s - loss: 0.0185 - val_loss: 0.0147
# Epoch 18/50
#  - 2s - loss: 0.0184 - val_loss: 0.0149
# Epoch 19/50
#  - 2s - loss: 0.0184 - val_loss: 0.0141
# Epoch 20/50
#  - 2s - loss: 0.0183 - val_loss: 0.0142
# Epoch 21/50
#  - 2s - loss: 0.0183 - val_loss: 0.0141
# Epoch 22/50
#  - 2s - loss: 0.0184 - val_loss: 0.0142
# Epoch 23/50
#  - 1s - loss: 0.0182 - val_loss: 0.0141
# Epoch 24/50
#  - 1s - loss: 0.0181 - val_loss: 0.0140
# Epoch 25/50
#  - 2s - loss: 0.0183 - val_loss: 0.0145
# Epoch 26/50
#  - 2s - loss: 0.0184 - val_loss: 0.0144
# Epoch 27/50
#  - 1s - loss: 0.0183 - val_loss: 0.0140
# Epoch 28/50
#  - 1s - loss: 0.0183 - val_loss: 0.0142
# Epoch 29/50
#  - 2s - loss: 0.0182 - val_loss: 0.0140
# Epoch 30/50
#  - 2s - loss: 0.0182 - val_loss: 0.0141
# Epoch 31/50
#  - 1s - loss: 0.0182 - val_loss: 0.0141
# Epoch 32/50
#  - 1s - loss: 0.0182 - val_loss: 0.0141
# Epoch 33/50
#  - 1s - loss: 0.0181 - val_loss: 0.0140
# Epoch 34/50
#  - 1s - loss: 0.0181 - val_loss: 0.0141
# Epoch 35/50
#  - 1s - loss: 0.0181 - val_loss: 0.0141
# Epoch 36/50
#  - 1s - loss: 0.0181 - val_loss: 0.0142
# Epoch 37/50
#  - 1s - loss: 0.0180 - val_loss: 0.0141
# Epoch 38/50
#  - 2s - loss: 0.0180 - val_loss: 0.0141
# Epoch 39/50
#  - 2s - loss: 0.0181 - val_loss: 0.0141
# Epoch 40/50
#  - 2s - loss: 0.0181 - val_loss: 0.0141
# Epoch 41/50
#  - 2s - loss: 0.0181 - val_loss: 0.0141
# Epoch 42/50
#  - 2s - loss: 0.0181 - val_loss: 0.0140
# Epoch 43/50
#  - 1s - loss: 0.0181 - val_loss: 0.0140
# Epoch 44/50
#  - 1s - loss: 0.0181 - val_loss: 0.0141
# Epoch 45/50
#  - 2s - loss: 0.0181 - val_loss: 0.0141
# Epoch 46/50
#  - 2s - loss: 0.0181 - val_loss: 0.0139
# Epoch 47/50
#  - 2s - loss: 0.0181 - val_loss: 0.0139
# Epoch 48/50
#  - 2s - loss: 0.0181 - val_loss: 0.0140
# Epoch 49/50
#  - 1s - loss: 0.0181 - val_loss: 0.0140
# Epoch 50/50
#  - 1s - loss: 0.0181 - val_loss: 0.0140
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC004463.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.024380   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.043199   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.046193   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.046193   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.046193   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.043199
# 2   0.508475   0.403581   0.909091  0.046193
# 3   0.519855   0.414601   0.870130  0.046193
# 4   0.519855   0.414601   0.870130  0.046193
# 5   0.516465   0.362948   0.883117  0.046193
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0353 - val_loss: 0.0374
# Epoch 2/50
#  - 2s - loss: 0.0303 - val_loss: 0.0368
# Epoch 3/50
#  - 2s - loss: 0.0297 - val_loss: 0.0371
# Epoch 4/50
#  - 2s - loss: 0.0297 - val_loss: 0.0369
# Epoch 5/50
#  - 2s - loss: 0.0294 - val_loss: 0.0368
# Epoch 6/50
#  - 2s - loss: 0.0294 - val_loss: 0.0370
# Epoch 7/50
#  - 2s - loss: 0.0291 - val_loss: 0.0368
# Epoch 8/50
#  - 2s - loss: 0.0289 - val_loss: 0.0368
# Epoch 9/50
#  - 2s - loss: 0.0288 - val_loss: 0.0370
# Epoch 10/50
#  - 2s - loss: 0.0288 - val_loss: 0.0371
# Epoch 11/50
#  - 2s - loss: 0.0286 - val_loss: 0.0372
# Epoch 12/50
#  - 2s - loss: 0.0286 - val_loss: 0.0374
# Epoch 13/50
#  - 2s - loss: 0.0286 - val_loss: 0.0375
# Epoch 14/50
#  - 2s - loss: 0.0284 - val_loss: 0.0376
# Epoch 15/50
#  - 2s - loss: 0.0284 - val_loss: 0.0379
# Epoch 16/50
#  - 1s - loss: 0.0283 - val_loss: 0.0377
# Epoch 17/50
#  - 1s - loss: 0.0283 - val_loss: 0.0377
# Epoch 18/50
#  - 1s - loss: 0.0283 - val_loss: 0.0381
# Epoch 19/50
#  - 1s - loss: 0.0282 - val_loss: 0.0380
# Epoch 20/50
#  - 1s - loss: 0.0282 - val_loss: 0.0383
# Epoch 21/50
#  - 1s - loss: 0.0282 - val_loss: 0.0383
# Epoch 22/50
#  - 1s - loss: 0.0281 - val_loss: 0.0381
# Epoch 23/50
#  - 1s - loss: 0.0283 - val_loss: 0.0384
# Epoch 24/50
#  - 1s - loss: 0.0281 - val_loss: 0.0384
# Epoch 25/50
#  - 1s - loss: 0.0282 - val_loss: 0.0384
# Epoch 26/50
#  - 1s - loss: 0.0279 - val_loss: 0.0383
# Epoch 27/50
#  - 1s - loss: 0.0281 - val_loss: 0.0384
# Epoch 28/50
#  - 1s - loss: 0.0281 - val_loss: 0.0385
# Epoch 29/50
#  - 1s - loss: 0.0279 - val_loss: 0.0385
# Epoch 30/50
#  - 1s - loss: 0.0280 - val_loss: 0.0384
# Epoch 31/50
#  - 1s - loss: 0.0280 - val_loss: 0.0385
# Epoch 32/50
#  - 1s - loss: 0.0280 - val_loss: 0.0384
# Epoch 33/50
#  - 1s - loss: 0.0280 - val_loss: 0.0384
# Epoch 34/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 35/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 36/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 37/50
#  - 1s - loss: 0.0279 - val_loss: 0.0383
# Epoch 38/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 39/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 40/50
#  - 1s - loss: 0.0278 - val_loss: 0.0383
# Epoch 41/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 42/50
#  - 1s - loss: 0.0279 - val_loss: 0.0384
# Epoch 43/50
#  - 1s - loss: 0.0278 - val_loss: 0.0383
# Epoch 44/50
#  - 1s - loss: 0.0278 - val_loss: 0.0383
# Epoch 45/50
#  - 1s - loss: 0.0278 - val_loss: 0.0384
# Epoch 46/50
#  - 1s - loss: 0.0278 - val_loss: 0.0385
# Epoch 47/50
#  - 1s - loss: 0.0277 - val_loss: 0.0385
# Epoch 48/50
#  - 1s - loss: 0.0278 - val_loss: 0.0385
# Epoch 49/50
#  - 1s - loss: 0.0278 - val_loss: 0.0384
# Epoch 50/50
#  - 1s - loss: 0.0278 - val_loss: 0.0385
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC004509.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.275171   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.192255   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.287016   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.201367   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.207289   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.192255
# 2   0.508475   0.403581   0.909091  0.287016
# 3   0.519855   0.414601   0.870130  0.201367
# 4   0.519855   0.414601   0.870130  0.207289
# 5   0.516465   0.362948   0.883117  0.235991
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0490 - val_loss: 0.0546
# Epoch 2/50
#  - 1s - loss: 0.0436 - val_loss: 0.0533
# Epoch 3/50
#  - 1s - loss: 0.0434 - val_loss: 0.0525
# Epoch 4/50
#  - 1s - loss: 0.0432 - val_loss: 0.0518
# Epoch 5/50
#  - 1s - loss: 0.0430 - val_loss: 0.0514
# Epoch 6/50
#  - 1s - loss: 0.0429 - val_loss: 0.0512
# Epoch 7/50
#  - 1s - loss: 0.0428 - val_loss: 0.0509
# Epoch 8/50
#  - 2s - loss: 0.0427 - val_loss: 0.0506
# Epoch 9/50
#  - 1s - loss: 0.0427 - val_loss: 0.0505
# Epoch 10/50
#  - 1s - loss: 0.0426 - val_loss: 0.0505
# Epoch 11/50
#  - 2s - loss: 0.0425 - val_loss: 0.0504
# Epoch 12/50
#  - 2s - loss: 0.0425 - val_loss: 0.0501
# Epoch 13/50
#  - 1s - loss: 0.0425 - val_loss: 0.0501
# Epoch 14/50
#  - 2s - loss: 0.0424 - val_loss: 0.0499
# Epoch 15/50
#  - 2s - loss: 0.0424 - val_loss: 0.0500
# Epoch 16/50
#  - 2s - loss: 0.0424 - val_loss: 0.0502
# Epoch 17/50
#  - 2s - loss: 0.0424 - val_loss: 0.0500
# Epoch 18/50
#  - 2s - loss: 0.0424 - val_loss: 0.0499
# Epoch 19/50
#  - 2s - loss: 0.0424 - val_loss: 0.0502
# Epoch 20/50
#  - 1s - loss: 0.0424 - val_loss: 0.0501
# Epoch 21/50
#  - 1s - loss: 0.0424 - val_loss: 0.0501
# Epoch 22/50
#  - 3s - loss: 0.0424 - val_loss: 0.0502
# Epoch 23/50
#  - 2s - loss: 0.0423 - val_loss: 0.0503
# Epoch 24/50
#  - 3s - loss: 0.0424 - val_loss: 0.0502
# Epoch 25/50
#  - 3s - loss: 0.0423 - val_loss: 0.0500
# Epoch 26/50
#  - 3s - loss: 0.0423 - val_loss: 0.0501
# Epoch 27/50
#  - 2s - loss: 0.0423 - val_loss: 0.0500
# Epoch 28/50
#  - 2s - loss: 0.0424 - val_loss: 0.0501
# Epoch 29/50
#  - 1s - loss: 0.0424 - val_loss: 0.0500
# Epoch 30/50
#  - 1s - loss: 0.0424 - val_loss: 0.0500
# Epoch 31/50
#  - 1s - loss: 0.0424 - val_loss: 0.0500
# Epoch 32/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 33/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 34/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 35/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 36/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 37/50
#  - 2s - loss: 0.0423 - val_loss: 0.0501
# Epoch 38/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 39/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 40/50
#  - 2s - loss: 0.0423 - val_loss: 0.0501
# Epoch 41/50
#  - 2s - loss: 0.0423 - val_loss: 0.0501
# Epoch 42/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 43/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 44/50
#  - 1s - loss: 0.0423 - val_loss: 0.0501
# Epoch 45/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 46/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 47/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 48/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 49/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Epoch 50/50
#  - 1s - loss: 0.0423 - val_loss: 0.0500
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC004455.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.014810   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.011715   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.011052   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.012378   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.015915   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.011715
# 2   0.508475   0.403581   0.909091  0.011052
# 3   0.519855   0.414601   0.870130  0.012378
# 4   0.519855   0.414601   0.870130  0.015915
# 5   0.516465   0.362948   0.883117  0.030725
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0438 - val_loss: 0.0412
# Epoch 2/50
#  - 2s - loss: 0.0397 - val_loss: 0.0413
# Epoch 3/50
#  - 1s - loss: 0.0393 - val_loss: 0.0407
# Epoch 4/50
#  - 1s - loss: 0.0389 - val_loss: 0.0398
# Epoch 5/50
#  - 1s - loss: 0.0386 - val_loss: 0.0397
# Epoch 6/50
#  - 1s - loss: 0.0382 - val_loss: 0.0391
# Epoch 7/50
#  - 1s - loss: 0.0380 - val_loss: 0.0398
# Epoch 8/50
#  - 1s - loss: 0.0377 - val_loss: 0.0392
# Epoch 9/50
#  - 1s - loss: 0.0375 - val_loss: 0.0378
# Epoch 10/50
#  - 1s - loss: 0.0374 - val_loss: 0.0376
# Epoch 11/50
#  - 2s - loss: 0.0374 - val_loss: 0.0375
# Epoch 12/50
#  - 2s - loss: 0.0374 - val_loss: 0.0374
# Epoch 13/50
#  - 2s - loss: 0.0373 - val_loss: 0.0373
# Epoch 14/50
#  - 2s - loss: 0.0373 - val_loss: 0.0377
# Epoch 15/50
#  - 2s - loss: 0.0373 - val_loss: 0.0376
# Epoch 16/50
#  - 2s - loss: 0.0373 - val_loss: 0.0375
# Epoch 17/50
#  - 2s - loss: 0.0372 - val_loss: 0.0377
# Epoch 18/50
#  - 2s - loss: 0.0372 - val_loss: 0.0374
# Epoch 19/50
#  - 2s - loss: 0.0372 - val_loss: 0.0373
# Epoch 20/50
#  - 2s - loss: 0.0372 - val_loss: 0.0373
# Epoch 21/50
#  - 1s - loss: 0.0372 - val_loss: 0.0373
# Epoch 22/50
#  - 1s - loss: 0.0372 - val_loss: 0.0373
# Epoch 23/50
#  - 1s - loss: 0.0372 - val_loss: 0.0373
# Epoch 24/50
#  - 1s - loss: 0.0371 - val_loss: 0.0374
# Epoch 25/50
#  - 1s - loss: 0.0372 - val_loss: 0.0373
# Epoch 26/50
#  - 1s - loss: 0.0372 - val_loss: 0.0373
# Epoch 27/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 28/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 29/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 30/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 31/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 32/50
#  - 2s - loss: 0.0371 - val_loss: 0.0373
# Epoch 33/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 34/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 35/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 36/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 37/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 38/50
#  - 2s - loss: 0.0371 - val_loss: 0.0373
# Epoch 39/50
#  - 2s - loss: 0.0371 - val_loss: 0.0373
# Epoch 40/50
#  - 1s - loss: 0.0371 - val_loss: 0.0373
# Epoch 41/50
#  - 2s - loss: 0.0370 - val_loss: 0.0373
# Epoch 42/50
#  - 2s - loss: 0.0371 - val_loss: 0.0373
# Epoch 43/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 44/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 45/50
#  - 1s - loss: 0.0370 - val_loss: 0.0374
# Epoch 46/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 47/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 48/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 49/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Epoch 50/50
#  - 1s - loss: 0.0370 - val_loss: 0.0373
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC004494.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.115551   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.117959   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.039961   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.030332   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.028888   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.117959
# 2   0.508475   0.403581   0.909091  0.039961
# 3   0.519855   0.414601   0.870130  0.030332
# 4   0.519855   0.414601   0.870130  0.028888
# 5   0.516465   0.362948   0.883117  0.014925
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0497 - val_loss: 0.0438
# Epoch 2/50
#  - 1s - loss: 0.0416 - val_loss: 0.0428
# Epoch 3/50
#  - 1s - loss: 0.0412 - val_loss: 0.0424
# Epoch 4/50
#  - 1s - loss: 0.0409 - val_loss: 0.0419
# Epoch 5/50
#  - 1s - loss: 0.0405 - val_loss: 0.0417
# Epoch 6/50
#  - 1s - loss: 0.0403 - val_loss: 0.0413
# Epoch 7/50
#  - 1s - loss: 0.0401 - val_loss: 0.0411
# Epoch 8/50
#  - 1s - loss: 0.0398 - val_loss: 0.0408
# Epoch 9/50
#  - 1s - loss: 0.0397 - val_loss: 0.0408
# Epoch 10/50
#  - 1s - loss: 0.0396 - val_loss: 0.0410
# Epoch 11/50
#  - 1s - loss: 0.0395 - val_loss: 0.0410
# Epoch 12/50
#  - 1s - loss: 0.0394 - val_loss: 0.0411
# Epoch 13/50
#  - 1s - loss: 0.0393 - val_loss: 0.0409
# Epoch 14/50
#  - 1s - loss: 0.0393 - val_loss: 0.0409
# Epoch 15/50
#  - 1s - loss: 0.0393 - val_loss: 0.0410
# Epoch 16/50
#  - 1s - loss: 0.0393 - val_loss: 0.0410
# Epoch 17/50
#  - 1s - loss: 0.0393 - val_loss: 0.0410
# Epoch 18/50
#  - 1s - loss: 0.0392 - val_loss: 0.0409
# Epoch 19/50
#  - 1s - loss: 0.0392 - val_loss: 0.0410
# Epoch 20/50
#  - 1s - loss: 0.0392 - val_loss: 0.0410
# Epoch 21/50
#  - 1s - loss: 0.0392 - val_loss: 0.0410
# Epoch 22/50
#  - 1s - loss: 0.0392 - val_loss: 0.0409
# Epoch 23/50
#  - 1s - loss: 0.0392 - val_loss: 0.0409
# Epoch 24/50
#  - 1s - loss: 0.0391 - val_loss: 0.0409
# Epoch 25/50
#  - 1s - loss: 0.0392 - val_loss: 0.0410
# Epoch 26/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 27/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 28/50
#  - 1s - loss: 0.0391 - val_loss: 0.0409
# Epoch 29/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 30/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 31/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 32/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 33/50
#  - 1s - loss: 0.0391 - val_loss: 0.0411
# Epoch 34/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 35/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 36/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 37/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 38/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 39/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 40/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 41/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 42/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 43/50
#  - 1s - loss: 0.0391 - val_loss: 0.0410
# Epoch 44/50
#  - 1s - loss: 0.0391 - val_loss: 0.0411
# Epoch 45/50
#  - 1s - loss: 0.0391 - val_loss: 0.0412
# Epoch 46/50
#  - 1s - loss: 0.0391 - val_loss: 0.0411
# Epoch 47/50
#  - 1s - loss: 0.0390 - val_loss: 0.0411
# Epoch 48/50
#  - 1s - loss: 0.0391 - val_loss: 0.0411
# Epoch 49/50
#  - 1s - loss: 0.0391 - val_loss: 0.0411
# Epoch 50/50
#  - 1s - loss: 0.0391 - val_loss: 0.0412
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC004491.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.196644   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.138437   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.080755   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.074463   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.048243   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.138437
# 2   0.508475   0.403581   0.909091  0.080755
# 3   0.519855   0.414601   0.870130  0.074463
# 4   0.519855   0.414601   0.870130  0.048243
# 5   0.516465   0.362948   0.883117  0.077609
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0447 - val_loss: 0.0469
# Epoch 2/50
#  - 1s - loss: 0.0378 - val_loss: 0.0455
# Epoch 3/50
#  - 1s - loss: 0.0374 - val_loss: 0.0462
# Epoch 4/50
#  - 1s - loss: 0.0371 - val_loss: 0.0455
# Epoch 5/50
#  - 1s - loss: 0.0369 - val_loss: 0.0449
# Epoch 6/50
#  - 1s - loss: 0.0368 - val_loss: 0.0441
# Epoch 7/50
#  - 1s - loss: 0.0366 - val_loss: 0.0446
# Epoch 8/50
#  - 2s - loss: 0.0364 - val_loss: 0.0451
# Epoch 9/50
#  - 1s - loss: 0.0363 - val_loss: 0.0443
# Epoch 10/50
#  - 1s - loss: 0.0363 - val_loss: 0.0441
# Epoch 11/50
#  - 2s - loss: 0.0361 - val_loss: 0.0436
# Epoch 12/50
#  - 2s - loss: 0.0361 - val_loss: 0.0442
# Epoch 13/50
#  - 2s - loss: 0.0360 - val_loss: 0.0441
# Epoch 14/50
#  - 2s - loss: 0.0360 - val_loss: 0.0438
# Epoch 15/50
#  - 1s - loss: 0.0360 - val_loss: 0.0438
# Epoch 16/50
#  - 2s - loss: 0.0360 - val_loss: 0.0434
# Epoch 17/50
#  - 2s - loss: 0.0360 - val_loss: 0.0435
# Epoch 18/50
#  - 2s - loss: 0.0360 - val_loss: 0.0433
# Epoch 19/50
#  - 2s - loss: 0.0360 - val_loss: 0.0428
# Epoch 20/50
#  - 1s - loss: 0.0359 - val_loss: 0.0432
# Epoch 21/50
#  - 1s - loss: 0.0359 - val_loss: 0.0432
# Epoch 22/50
#  - 1s - loss: 0.0359 - val_loss: 0.0431
# Epoch 23/50
#  - 1s - loss: 0.0360 - val_loss: 0.0429
# Epoch 24/50
#  - 1s - loss: 0.0359 - val_loss: 0.0428
# Epoch 25/50
#  - 1s - loss: 0.0360 - val_loss: 0.0428
# Epoch 26/50
#  - 1s - loss: 0.0360 - val_loss: 0.0429
# Epoch 27/50
#  - 1s - loss: 0.0360 - val_loss: 0.0430
# Epoch 28/50
#  - 1s - loss: 0.0360 - val_loss: 0.0429
# Epoch 29/50
#  - 1s - loss: 0.0360 - val_loss: 0.0430
# Epoch 30/50
#  - 1s - loss: 0.0361 - val_loss: 0.0429
# Epoch 31/50
#  - 1s - loss: 0.0361 - val_loss: 0.0428
# Epoch 32/50
#  - 1s - loss: 0.0360 - val_loss: 0.0428
# Epoch 33/50
#  - 1s - loss: 0.0361 - val_loss: 0.0429
# Epoch 34/50
#  - 1s - loss: 0.0361 - val_loss: 0.0429
# Epoch 35/50
#  - 1s - loss: 0.0360 - val_loss: 0.0429
# Epoch 36/50
#  - 1s - loss: 0.0360 - val_loss: 0.0429
# Epoch 37/50
#  - 1s - loss: 0.0360 - val_loss: 0.0429
# Epoch 38/50
#  - 1s - loss: 0.0360 - val_loss: 0.0428
# Epoch 39/50
#  - 1s - loss: 0.0360 - val_loss: 0.0428
# Epoch 40/50
#  - 1s - loss: 0.0360 - val_loss: 0.0428
# Epoch 41/50
#  - 1s - loss: 0.0360 - val_loss: 0.0427
# Epoch 42/50
#  - 2s - loss: 0.0360 - val_loss: 0.0428
# Epoch 43/50
#  - 2s - loss: 0.0359 - val_loss: 0.0428
# Epoch 44/50
#  - 1s - loss: 0.0359 - val_loss: 0.0428
# Epoch 45/50
#  - 2s - loss: 0.0359 - val_loss: 0.0428
# Epoch 46/50
#  - 2s - loss: 0.0359 - val_loss: 0.0428
# Epoch 47/50
#  - 2s - loss: 0.0359 - val_loss: 0.0428
# Epoch 48/50
#  - 1s - loss: 0.0359 - val_loss: 0.0428
# Epoch 49/50
#  - 1s - loss: 0.0359 - val_loss: 0.0428
# Epoch 50/50
#  - 2s - loss: 0.0359 - val_loss: 0.0428
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000027.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.062462   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.062462   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.056398   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.068526   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.071559   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.062462
# 2   0.508475   0.403581   0.909091  0.056398
# 3   0.519855   0.414601   0.870130  0.068526
# 4   0.519855   0.414601   0.870130  0.071559
# 5   0.516465   0.362948   0.883117  0.067920
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0364 - val_loss: 0.0389
# Epoch 2/50
#  - 1s - loss: 0.0312 - val_loss: 0.0368
# Epoch 3/50
#  - 1s - loss: 0.0311 - val_loss: 0.0369
# Epoch 4/50
#  - 1s - loss: 0.0309 - val_loss: 0.0369
# Epoch 5/50
#  - 1s - loss: 0.0307 - val_loss: 0.0367
# Epoch 6/50
#  - 1s - loss: 0.0306 - val_loss: 0.0364
# Epoch 7/50
#  - 1s - loss: 0.0304 - val_loss: 0.0361
# Epoch 8/50
#  - 1s - loss: 0.0302 - val_loss: 0.0358
# Epoch 9/50
#  - 1s - loss: 0.0300 - val_loss: 0.0351
# Epoch 10/50
#  - 1s - loss: 0.0299 - val_loss: 0.0348
# Epoch 11/50
#  - 1s - loss: 0.0296 - val_loss: 0.0348
# Epoch 12/50
#  - 1s - loss: 0.0295 - val_loss: 0.0344
# Epoch 13/50
#  - 1s - loss: 0.0294 - val_loss: 0.0339
# Epoch 14/50
#  - 2s - loss: 0.0293 - val_loss: 0.0340
# Epoch 15/50
#  - 2s - loss: 0.0292 - val_loss: 0.0338
# Epoch 16/50
#  - 3s - loss: 0.0292 - val_loss: 0.0336
# Epoch 17/50
#  - 2s - loss: 0.0291 - val_loss: 0.0336
# Epoch 18/50
#  - 2s - loss: 0.0291 - val_loss: 0.0335
# Epoch 19/50
#  - 2s - loss: 0.0290 - val_loss: 0.0334
# Epoch 20/50
#  - 2s - loss: 0.0290 - val_loss: 0.0334
# Epoch 21/50
#  - 2s - loss: 0.0290 - val_loss: 0.0334
# Epoch 22/50
#  - 2s - loss: 0.0290 - val_loss: 0.0333
# Epoch 23/50
#  - 2s - loss: 0.0290 - val_loss: 0.0333
# Epoch 24/50
#  - 2s - loss: 0.0290 - val_loss: 0.0333
# Epoch 25/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 26/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 27/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 28/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 29/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 30/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 31/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 32/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 33/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 34/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 35/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 36/50
#  - 2s - loss: 0.0289 - val_loss: 0.0333
# Epoch 37/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 38/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 39/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 40/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 41/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 42/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 43/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 44/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 45/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 46/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 47/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 48/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 49/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Epoch 50/50
#  - 1s - loss: 0.0288 - val_loss: 0.0333
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000019.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.091968   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.026977   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.021459   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.036174   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.045371   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.026977
# 2   0.508475   0.403581   0.909091  0.021459
# 3   0.519855   0.414601   0.870130  0.036174
# 4   0.519855   0.414601   0.870130  0.045371
# 5   0.516465   0.362948   0.883117  0.003679
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0380 - val_loss: 0.0414
# Epoch 2/50
#  - 1s - loss: 0.0343 - val_loss: 0.0412
# Epoch 3/50
#  - 1s - loss: 0.0337 - val_loss: 0.0420
# Epoch 4/50
#  - 1s - loss: 0.0333 - val_loss: 0.0424
# Epoch 5/50
#  - 1s - loss: 0.0330 - val_loss: 0.0427
# Epoch 6/50
#  - 1s - loss: 0.0328 - val_loss: 0.0427
# Epoch 7/50
#  - 1s - loss: 0.0326 - val_loss: 0.0421
# Epoch 8/50
#  - 2s - loss: 0.0324 - val_loss: 0.0417
# Epoch 9/50
#  - 2s - loss: 0.0323 - val_loss: 0.0410
# Epoch 10/50
#  - 2s - loss: 0.0321 - val_loss: 0.0406
# Epoch 11/50
#  - 2s - loss: 0.0319 - val_loss: 0.0400
# Epoch 12/50
#  - 2s - loss: 0.0317 - val_loss: 0.0398
# Epoch 13/50
#  - 2s - loss: 0.0316 - val_loss: 0.0396
# Epoch 14/50
#  - 2s - loss: 0.0314 - val_loss: 0.0394
# Epoch 15/50
#  - 2s - loss: 0.0313 - val_loss: 0.0391
# Epoch 16/50
#  - 2s - loss: 0.0312 - val_loss: 0.0389
# Epoch 17/50
#  - 2s - loss: 0.0312 - val_loss: 0.0390
# Epoch 18/50
#  - 2s - loss: 0.0311 - val_loss: 0.0390
# Epoch 19/50
#  - 2s - loss: 0.0311 - val_loss: 0.0389
# Epoch 20/50
#  - 2s - loss: 0.0310 - val_loss: 0.0389
# Epoch 21/50
#  - 1s - loss: 0.0310 - val_loss: 0.0389
# Epoch 22/50
#  - 1s - loss: 0.0310 - val_loss: 0.0389
# Epoch 23/50
#  - 1s - loss: 0.0309 - val_loss: 0.0389
# Epoch 24/50
#  - 1s - loss: 0.0309 - val_loss: 0.0389
# Epoch 25/50
#  - 1s - loss: 0.0309 - val_loss: 0.0387
# Epoch 26/50
#  - 1s - loss: 0.0309 - val_loss: 0.0388
# Epoch 27/50
#  - 2s - loss: 0.0309 - val_loss: 0.0388
# Epoch 28/50
#  - 2s - loss: 0.0308 - val_loss: 0.0387
# Epoch 29/50
#  - 2s - loss: 0.0308 - val_loss: 0.0387
# Epoch 30/50
#  - 2s - loss: 0.0308 - val_loss: 0.0389
# Epoch 31/50
#  - 1s - loss: 0.0308 - val_loss: 0.0388
# Epoch 32/50
#  - 1s - loss: 0.0308 - val_loss: 0.0387
# Epoch 33/50
#  - 1s - loss: 0.0308 - val_loss: 0.0387
# Epoch 34/50
#  - 1s - loss: 0.0308 - val_loss: 0.0388
# Epoch 35/50
#  - 1s - loss: 0.0308 - val_loss: 0.0387
# Epoch 36/50
#  - 1s - loss: 0.0308 - val_loss: 0.0388
# Epoch 37/50
#  - 1s - loss: 0.0308 - val_loss: 0.0389
# Epoch 38/50
#  - 1s - loss: 0.0308 - val_loss: 0.0389
# Epoch 39/50
#  - 1s - loss: 0.0308 - val_loss: 0.0389
# Epoch 40/50
#  - 1s - loss: 0.0308 - val_loss: 0.0389
# Epoch 41/50
#  - 1s - loss: 0.0308 - val_loss: 0.0389
# Epoch 42/50
#  - 1s - loss: 0.0308 - val_loss: 0.0388
# Epoch 43/50
#  - 1s - loss: 0.0308 - val_loss: 0.0388
# Epoch 44/50
#  - 1s - loss: 0.0307 - val_loss: 0.0388
# Epoch 45/50
#  - 1s - loss: 0.0307 - val_loss: 0.0388
# Epoch 46/50
#  - 1s - loss: 0.0307 - val_loss: 0.0388
# Epoch 47/50
#  - 1s - loss: 0.0307 - val_loss: 0.0389
# Epoch 48/50
#  - 1s - loss: 0.0307 - val_loss: 0.0388
# Epoch 49/50
#  - 1s - loss: 0.0307 - val_loss: 0.0389
# Epoch 50/50
#  - 1s - loss: 0.0307 - val_loss: 0.0389
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000018.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1     0.0175   0.803549   0.637883   0.466877   0.718345   0.478840
# 2     0.0180   0.803549   0.637883   0.466877   0.718345   0.478840
# 3     0.0190   0.797212   0.662953   0.479232   0.720435   0.475585
# 4     0.0180   0.797212   0.662953   0.479232   0.720435   0.475585
# 5     0.0185   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)  var1(t)
# 1   0.508475   0.403581   0.909091   0.0180
# 2   0.508475   0.403581   0.909091   0.0190
# 3   0.519855   0.414601   0.870130   0.0180
# 4   0.519855   0.414601   0.870130   0.0185
# 5   0.516465   0.362948   0.883117   0.0180
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0382 - val_loss: 0.0134
# Epoch 2/50
#  - 1s - loss: 0.0262 - val_loss: 0.0122
# Epoch 3/50
#  - 1s - loss: 0.0262 - val_loss: 0.0108
# Epoch 4/50
#  - 1s - loss: 0.0260 - val_loss: 0.0113
# Epoch 5/50
#  - 2s - loss: 0.0259 - val_loss: 0.0109
# Epoch 6/50
#  - 1s - loss: 0.0256 - val_loss: 0.0105
# Epoch 7/50
#  - 1s - loss: 0.0258 - val_loss: 0.0120
# Epoch 8/50
#  - 1s - loss: 0.0258 - val_loss: 0.0115
# Epoch 9/50
#  - 1s - loss: 0.0256 - val_loss: 0.0116
# Epoch 10/50
#  - 1s - loss: 0.0257 - val_loss: 0.0105
# Epoch 11/50
#  - 1s - loss: 0.0252 - val_loss: 0.0110
# Epoch 12/50
#  - 1s - loss: 0.0253 - val_loss: 0.0101
# Epoch 13/50
#  - 1s - loss: 0.0252 - val_loss: 0.0122
# Epoch 14/50
#  - 1s - loss: 0.0254 - val_loss: 0.0143
# Epoch 15/50
#  - 1s - loss: 0.0253 - val_loss: 0.0101
# Epoch 16/50
#  - 1s - loss: 0.0251 - val_loss: 0.0092
# Epoch 17/50
#  - 1s - loss: 0.0251 - val_loss: 0.0094
# Epoch 18/50
#  - 1s - loss: 0.0252 - val_loss: 0.0123
# Epoch 19/50
#  - 1s - loss: 0.0252 - val_loss: 0.0093
# Epoch 20/50
#  - 1s - loss: 0.0251 - val_loss: 0.0125
# Epoch 21/50
#  - 1s - loss: 0.0252 - val_loss: 0.0091
# Epoch 22/50
#  - 1s - loss: 0.0251 - val_loss: 0.0093
# Epoch 23/50
#  - 2s - loss: 0.0251 - val_loss: 0.0118
# Epoch 24/50
#  - 2s - loss: 0.0250 - val_loss: 0.0094
# Epoch 25/50
#  - 2s - loss: 0.0251 - val_loss: 0.0122
# Epoch 26/50
#  - 2s - loss: 0.0250 - val_loss: 0.0107
# Epoch 27/50
#  - 1s - loss: 0.0250 - val_loss: 0.0096
# Epoch 28/50
#  - 1s - loss: 0.0250 - val_loss: 0.0096
# Epoch 29/50
#  - 1s - loss: 0.0250 - val_loss: 0.0096
# Epoch 30/50
#  - 1s - loss: 0.0250 - val_loss: 0.0095
# Epoch 31/50
#  - 1s - loss: 0.0250 - val_loss: 0.0090
# Epoch 32/50
#  - 2s - loss: 0.0250 - val_loss: 0.0098
# Epoch 33/50
#  - 2s - loss: 0.0249 - val_loss: 0.0090
# Epoch 34/50
#  - 2s - loss: 0.0249 - val_loss: 0.0093
# Epoch 35/50
#  - 1s - loss: 0.0249 - val_loss: 0.0091
# Epoch 36/50
#  - 1s - loss: 0.0250 - val_loss: 0.0089
# Epoch 37/50
#  - 1s - loss: 0.0249 - val_loss: 0.0102
# Epoch 38/50
#  - 1s - loss: 0.0249 - val_loss: 0.0090
# Epoch 39/50
#  - 1s - loss: 0.0249 - val_loss: 0.0091
# Epoch 40/50
#  - 1s - loss: 0.0249 - val_loss: 0.0089
# Epoch 41/50
#  - 1s - loss: 0.0249 - val_loss: 0.0091
# Epoch 42/50
#  - 1s - loss: 0.0249 - val_loss: 0.0092
# Epoch 43/50
#  - 1s - loss: 0.0249 - val_loss: 0.0091
# Epoch 44/50
#  - 1s - loss: 0.0249 - val_loss: 0.0092
# Epoch 45/50
#  - 1s - loss: 0.0249 - val_loss: 0.0089
# Epoch 46/50
#  - 1s - loss: 0.0248 - val_loss: 0.0090
# Epoch 47/50
#  - 1s - loss: 0.0248 - val_loss: 0.0090
# Epoch 48/50
#  - 2s - loss: 0.0249 - val_loss: 0.0090
# Epoch 49/50
#  - 1s - loss: 0.0248 - val_loss: 0.0091
# Epoch 50/50
#  - 1s - loss: 0.0248 - val_loss: 0.0090
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000255.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.093937   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.028314   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.023651   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.016989   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.019320   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.028314
# 2   0.508475   0.403581   0.909091  0.023651
# 3   0.519855   0.414601   0.870130  0.016989
# 4   0.519855   0.414601   0.870130  0.019320
# 5   0.516465   0.362948   0.883117  0.019987
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0401 - val_loss: 0.0354
# Epoch 2/50
#  - 2s - loss: 0.0357 - val_loss: 0.0349
# Epoch 3/50
#  - 2s - loss: 0.0354 - val_loss: 0.0344
# Epoch 4/50
#  - 2s - loss: 0.0352 - val_loss: 0.0342
# Epoch 5/50
#  - 2s - loss: 0.0351 - val_loss: 0.0339
# Epoch 6/50
#  - 2s - loss: 0.0349 - val_loss: 0.0336
# Epoch 7/50
#  - 2s - loss: 0.0347 - val_loss: 0.0334
# Epoch 8/50
#  - 2s - loss: 0.0347 - val_loss: 0.0334
# Epoch 9/50
#  - 2s - loss: 0.0346 - val_loss: 0.0332
# Epoch 10/50
#  - 2s - loss: 0.0345 - val_loss: 0.0330
# Epoch 11/50
#  - 2s - loss: 0.0344 - val_loss: 0.0329
# Epoch 12/50
#  - 2s - loss: 0.0344 - val_loss: 0.0328
# Epoch 13/50
#  - 2s - loss: 0.0344 - val_loss: 0.0328
# Epoch 14/50
#  - 2s - loss: 0.0343 - val_loss: 0.0327
# Epoch 15/50
#  - 2s - loss: 0.0343 - val_loss: 0.0327
# Epoch 16/50
#  - 2s - loss: 0.0343 - val_loss: 0.0327
# Epoch 17/50
#  - 2s - loss: 0.0343 - val_loss: 0.0327
# Epoch 18/50
#  - 2s - loss: 0.0343 - val_loss: 0.0327
# Epoch 19/50
#  - 1s - loss: 0.0343 - val_loss: 0.0327
# Epoch 20/50
#  - 2s - loss: 0.0342 - val_loss: 0.0327
# Epoch 21/50
#  - 2s - loss: 0.0342 - val_loss: 0.0327
# Epoch 22/50
#  - 1s - loss: 0.0342 - val_loss: 0.0327
# Epoch 23/50
#  - 2s - loss: 0.0342 - val_loss: 0.0326
# Epoch 24/50
#  - 1s - loss: 0.0342 - val_loss: 0.0327
# Epoch 25/50
#  - 2s - loss: 0.0342 - val_loss: 0.0327
# Epoch 26/50
#  - 1s - loss: 0.0342 - val_loss: 0.0327
# Epoch 27/50
#  - 1s - loss: 0.0342 - val_loss: 0.0327
# Epoch 28/50
#  - 1s - loss: 0.0342 - val_loss: 0.0327
# Epoch 29/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 30/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 31/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 32/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 33/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 34/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 35/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 36/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 37/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 38/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 39/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 40/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 41/50
#  - 1s - loss: 0.0342 - val_loss: 0.0326
# Epoch 42/50
#  - 2s - loss: 0.0342 - val_loss: 0.0326
# Epoch 43/50
#  - 2s - loss: 0.0341 - val_loss: 0.0326
# Epoch 44/50
#  - 1s - loss: 0.0342 - val_loss: 0.0327
# Epoch 45/50
#  - 2s - loss: 0.0342 - val_loss: 0.0326
# Epoch 46/50
#  - 1s - loss: 0.0341 - val_loss: 0.0326
# Epoch 47/50
#  - 2s - loss: 0.0342 - val_loss: 0.0327
# Epoch 48/50
#  - 2s - loss: 0.0341 - val_loss: 0.0327
# Epoch 49/50
#  - 1s - loss: 0.0342 - val_loss: 0.0328
# Epoch 50/50
#  - 1s - loss: 0.0341 - val_loss: 0.0328
# Calculating metrics
# /Users/mariabelenalberti/OneDrive - Universidad Torcuato Di Tella/Tesis/code_datasets/1_data_frames/multivariate/MAC000131.csv
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.021837   0.803549   0.637883   0.466877   0.718345   0.478840
# 2   0.073218   0.803549   0.637883   0.466877   0.718345   0.478840
# 3   0.039820   0.797212   0.662953   0.479232   0.720435   0.475585
# 4   0.019910   0.797212   0.662953   0.479232   0.720435   0.475585
# 5   0.023764   0.711660   0.637883   0.475552   0.721270   0.476621
#
#    var7(t-1)  var8(t-1)  var9(t-1)   var1(t)
# 1   0.508475   0.403581   0.909091  0.073218
# 2   0.508475   0.403581   0.909091  0.039820
# 3   0.519855   0.414601   0.870130  0.019910
# 4   0.519855   0.414601   0.870130  0.023764
# 5   0.516465   0.362948   0.883117  0.018626
# Splitting into train and test
# (33600, 1, 9) (33600,) (1455, 1, 9) (1455,)
# Designing network
# Fitting network
# Train on 33600 samples, validate on 1455 samples
# Epoch 1/50
#  - 2s - loss: 0.0532 - val_loss: 0.0499
# Epoch 2/50
#  - 1s - loss: 0.0430 - val_loss: 0.0497
# Epoch 3/50
#  - 1s - loss: 0.0427 - val_loss: 0.0497
# Epoch 4/50
#  - 1s - loss: 0.0427 - val_loss: 0.0508
# Epoch 5/50
#  - 1s - loss: 0.0427 - val_loss: 0.0498
# Epoch 6/50
#  - 1s - loss: 0.0424 - val_loss: 0.0518
# Epoch 7/50
#  - 2s - loss: 0.0424 - val_loss: 0.0487
# Epoch 8/50
#  - 2s - loss: 0.0423 - val_loss: 0.0487
# Epoch 9/50
#  - 2s - loss: 0.0424 - val_loss: 0.0489
# Epoch 10/50
#  - 1s - loss: 0.0424 - val_loss: 0.0502
# Epoch 11/50
#  - 2s - loss: 0.0423 - val_loss: 0.0486
# Epoch 12/50
#  - 2s - loss: 0.0422 - val_loss: 0.0493
# Epoch 13/50
#  - 1s - loss: 0.0422 - val_loss: 0.0486
# Epoch 14/50
#  - 2s - loss: 0.0423 - val_loss: 0.0488
# Epoch 15/50
#  - 3s - loss: 0.0421 - val_loss: 0.0486
# Epoch 16/50
#  - 2s - loss: 0.0422 - val_loss: 0.0486
# Epoch 17/50
#  - 2s - loss: 0.0421 - val_loss: 0.0486
# Epoch 18/50
#  - 2s - loss: 0.0421 - val_loss: 0.0486
# Epoch 19/50
#  - 2s - loss: 0.0421 - val_loss: 0.0486
# Epoch 20/50
#  - 2s - loss: 0.0421 - val_loss: 0.0488
# Epoch 21/50
#  - 1s - loss: 0.0421 - val_loss: 0.0486
# Epoch 22/50
#  - 2s - loss: 0.0420 - val_loss: 0.0488
# Epoch 23/50
#  - 2s - loss: 0.0420 - val_loss: 0.0486
# Epoch 24/50
#  - 1s - loss: 0.0420 - val_loss: 0.0488
# Epoch 25/50
#  - 2s - loss: 0.0420 - val_loss: 0.0487
# Epoch 26/50
#  - 1s - loss: 0.0420 - val_loss: 0.0487
# Epoch 27/50
#  - 2s - loss: 0.0420 - val_loss: 0.0486
# Epoch 28/50
#  - 2s - loss: 0.0420 - val_loss: 0.0488
# Epoch 29/50
#  - 1s - loss: 0.0420 - val_loss: 0.0487
# Epoch 30/50
#  - 1s - loss: 0.0419 - val_loss: 0.0487
# Epoch 31/50
#  - 2s - loss: 0.0419 - val_loss: 0.0487
# Epoch 32/50
#  - 2s - loss: 0.0419 - val_loss: 0.0486
# Epoch 33/50
#  - 2s - loss: 0.0419 - val_loss: 0.0489
# Epoch 34/50
#  - 2s - loss: 0.0419 - val_loss: 0.0486
# Epoch 35/50
#  - 1s - loss: 0.0419 - val_loss: 0.0488
# Epoch 36/50
#  - 1s - loss: 0.0419 - val_loss: 0.0487
# Epoch 37/50
#  - 3s - loss: 0.0419 - val_loss: 0.0488
# Epoch 38/50
#  - 3s - loss: 0.0419 - val_loss: 0.0487
# Epoch 39/50
#  - 4s - loss: 0.0418 - val_loss: 0.0487
# Epoch 40/50
#  - 3s - loss: 0.0418 - val_loss: 0.0485
# Epoch 41/50
#  - 2s - loss: 0.0418 - val_loss: 0.0488
# Epoch 42/50
#  - 2s - loss: 0.0418 - val_loss: 0.0488
# Epoch 43/50
#  - 2s - loss: 0.0418 - val_loss: 0.0486
# Epoch 44/50
#  - 2s - loss: 0.0418 - val_loss: 0.0486
# Epoch 45/50
#  - 2s - loss: 0.0418 - val_loss: 0.0485
# Epoch 46/50
#  - 2s - loss: 0.0417 - val_loss: 0.0484
# Epoch 47/50
#  - 2s - loss: 0.0418 - val_loss: 0.0485
# Epoch 48/50
#  - 2s - loss: 0.0418 - val_loss: 0.0485
# Epoch 49/50
#  - 2s - loss: 0.0418 - val_loss: 0.0484
# Epoch 50/50
#  - 2s - loss: 0.0418 - val_loss: 0.0484
# Calculating metrics

# %%
print(mae_t)
# Out:
# [0.32720992, 0.03775454, 0.089904085, 0.1097296, 0.16885744, 0.0855102, 0.08163053, 0.054875378, 0.06347193, 0.017912468, 0.098383866, 0.07537179]
